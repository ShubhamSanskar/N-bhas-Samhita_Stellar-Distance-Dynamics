# %% [markdown]
# Practical Use and Real-Life Applications:
# **1. Astronomical Research and Data Analysis:
#
# Description: The project involves predicting and analyzing distances related to astronomical objects such as star-forming regions and nearest stars. Understanding these distances can provide valuable insights into the structure and dynamics of our galaxy.
# Use Case: Researchers can use predictive models to estimate the positions and movements of celestial objects over time, improving our understanding of cosmic phenomena.
# **2. Space Exploration and Mission Planning:
#
# Description: Accurate distance predictions are crucial for space missions, including planning travel routes and mission objectives.
# Use Case: Space agencies can leverage these predictions to design better spacecraft trajectories and optimize mission parameters, ensuring successful exploration and data collection.
# **3. Astronomical Database Management:
#
# Description: Handling large datasets of celestial objects and their distances can be challenging.
# Use Case: This project can contribute to the development of advanced database systems and tools for managing and querying astronomical data, improving data accessibility and usability.
# **4. Educational Tools and Visualization:
#
# Description: Visualizing changes in distances and model performances can enhance educational resources for teaching astronomy and data science.
# Use Case: Educators can use the visualizations to explain complex concepts in astronomy and machine learning, making the subjects more engaging and comprehensible for students.
# **5. Model Optimization and Predictive Analytics:
#
# Description: The evaluation of different regression models and their performance metrics (MSE and R²) can be applied to various fields requiring predictive analytics.
# Use Case: The techniques used in this project can be adapted for other domains where predictive modeling is essential, such as financial forecasting, healthcare diagnostics, and industrial process optimization.
# Summary:
# The "Celestial Analytics" project combines data analysis, predictive modeling, and visualization to advance our understanding of astronomical distances and enhance the tools and techniques used in this field. Its practical applications span research, space exploration, database management, education, and predictive analytics, contributing to both scientific and practical advancements.

# %%
# Brief overview of each library used:
# numpy: Efficient handling of arrays and mathematical functions
# pandas: Powerful data structures for data analysis, particularly DataFrame
# matplotlib.pyplot: Plotting and visualization
# seaborn: Statistical data visualization built on top of matplotlib
# sklearn.model_selection: Tools for splitting data into train and test sets
# sklearn.preprocessing: Data preprocessing utilities like scaling
# sklearn.linear_model: Linear regression models including regularized versions (Ridge, Lasso)
# sklearn.ensemble: Ensemble methods for regression such as Random Forest and Gradient Boosting
# sklearn.metrics: Performance metrics for evaluating models
# astropy.units: Handling of physical units
# astropy.coordinates: Astronomical coordinate transformations
# IPython.display: Tools for displaying rich media (like HTML) in Jupyter Notebooks

# %%
# Importing necessary libraries for data manipulation, visualization, and machine learning

# Numerical operations and array manipulation
import numpy as np

# Data manipulation and analysis
import pandas as pd

# Data visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Libraries for model training and evaluation
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Astronomy-specific utilities for coordinate transformations and calculations
from astropy import units as u
from astropy.coordinates import SkyCoord

# For displaying HTML content in Jupyter Notebooks
from IPython.display import display, HTML

# %%
# Reading a CSV file into a DataFrame and displaying the first three rows

# Load the CSV file named '88-constellations.csv' into a DataFrame.
# The file is assumed to be separated by semicolons (';').
# The 'on_bad_lines' parameter is set to 'skip' to ignore and skip any malformed lines in the file.
df = pd.read_csv('88-constellations.csv', sep=';', on_bad_lines='skip')

# Display the first three rows of the DataFrame to get an initial glimpse of the data.
df.head(3)
# Out:
#            Observation Season / Saison d'observation IAU code  \
# 0                                       Summer / Été      Sct
# 1  Southern hemisphere constellation / Constellat...      Vol
# 2  Southern hemisphere constellation / Constellat...      Tuc
#
#   Latin name / Nom latin  French name / Nom français   \
# 0                  Scutum           L’Écu de Sobieski
# 1                  Volans              Poisson volant
# 2                  Tucana                      Toucan
#
#   English name / Nom en anglais  \
# 0                        Shield
# 1                   Flying Fish
# 2                        Toucan
#
#    Constellation area in square degrees / Étendue de la constellation en degrés carrés  \
# 0                                            109.114
# 1                                            141.354
# 2                                            294.557
#
#   Dec (Declinaison) RA (Right Ascension / Ascension droite)  \
# 0       -09° 53,32'                                15:54,18
# 1       -69° 48,07'                                13:24,39
# 2       +31° 28,56'                                23:46,64
#
#   Principal star / Étoile principale  \
# 0                            α Scuti
# 1                         β Volantis
# 2                          α Tucanae
#
#   Constellation area in % of the celestial sphere / Étendue de la constellation en % de la sphère céleste  \
# 0                                             0,26 %
# 1                                             0,34 %
# 2                                             0,71 %
#
#   Constellation zone (celestial equator) / Zone de la constellation (équateur céleste)  \
# 0                                South constellation
# 1                                South constellation
# 2                                South constellation
#
#   Constellation zone (ecliptic) / Zone de la constellation (écliptique)  \
# 0                       South ecliptic constellation
# 1                       South ecliptic constellation
# 2                       South ecliptic constellation
#
#   Constellation zone (Milky Way) / Zone de la constellation (Voie Lactée)  \
# 0                                  Milky Way Equator
# 1                                                NaN
# 2                                                NaN
#
#                           Quad Name origin / Origine de l'apellation  \
# 0  South Hemisphere Quadrant 4                              Hevelius
# 1  South Hemisphere Quadrant 2                                 Bayer
# 2  North Hemisphere Quadrant 1                                 Bayer
#
#                                                Image
# 0  https://www.datastro.eu/api/explore/v2.1/catal...
# 1  https://www.datastro.eu/api/explore/v2.1/catal...
# 2  https://www.datastro.eu/api/explore/v2.1/catal...

# %%
# Checking for non-numeric values or unexpected characters in specific columns

# Print unique values in the 'Dec (Declinaison)' column to check for any non-numeric or unexpected characters
print(df['Dec (Declinaison)'].unique())

# Print unique values in the 'RA (Right Ascension / Ascension droite)' column to check for any non-numeric or unexpected characters
print(df['RA (Right Ascension / Ascension droite)'].unique())
# Out:
# ["-09° 53,32'" "-69° 48,07'" "+31° 28,56'" "+50° 43,27'" "+32° 23,28'"
#  "+24° 26,56'" "+22° 36,01'" "-35° 05,67'" "+06° 25,63'" "-60° 11,19'"
#  "+40° 06,11'" "+13° 08,32'" "+36° 41,36'" "-32° 05,30'" "-36° 16,49'"
#  "-30° 38,53'" "+03° 24,65'" "+71° 00,51'" "-56° 35,30'" "+69° 22,89'"
#  "-07° 10,76'" "-47° 20,72'" "-47° 10,03'" "+62° 11,04'" "-51° 21,09'"
#  "-15° 14,08'" "+46° 02,51'" "-59° 59,85'" "-27° 21,10'" "-65° 46,89'"
#  "-07° 54,74'" "-42° 42,53'" "-53° 20,18'" "-77° 30,24'" "-19° 02,78'"
#  "-28° 28,61'" "+77° 41,99'" "+06° 07,32'" "-59° 23,22'" "-46° 21,11'"
#  "+27° 29,93'" "+44° 32,70'" "-41° 08,85'" "+47° 28,00'" "+00° 16,93'"
#  "-51° 02,21'" "-48° 34,84'" "-04° 09,51'" "+18° 51,68'" "-22° 08,42'"
#  "+42° 01,68'" "-63° 01,82'" "-32° 29,01'" "-10° 47,35'" "+37° 25,91'"
#  "+31° 12,16'" "+20° 47,54'" "+23° 18,34'" "-14° 31,91'" "+11° 40,26'"
#  "-18° 26,20'" "+67° 00,40'" "+14° 52,63'" "-82° 09,12'" "-02° 36,88'"
#  "-59° 42,40'" "-70° 09,66'" "+13° 41,23'" "+19° 27,98'" "-65° 49,80'"
#  "-37° 52,90'" "+07° 45,49'" "-28° 45,37'" "-69° 57,39'" "+32° 37,49'"
#  "+32° 08,08'" "+45° 00,79'" "-63° 13,16'" "-75° 18,00'" "-79° 12,30'"
#  "-18° 01,39'" "+19° 48,35'" "-31° 38,07'" "-15° 55,74'" "-31° 10,64'"
#  "-27° 01,89'" "+05° 56,94'" "-53° 28,45'"]
# ['15:54,18' '13:24,39' '23:46,64' '02:11,07' '04:42,13' '09:34,64'
#  '11:18,76' '11:23,75' '14:34,54' '20:41,61' '15:08,64' '07:03,63'
#  '10:16,43' '00:28,97' '12:35,28' '20:13,88' '15:11,96' '22:00,00'
#  '02:38,16' '08:38,96' '12:47,27' '13:04,27' '19:19,54' '01:19,16'
#  '17:23,69' '10:40,03' '22:27,68' '07:47,73' '22:17,07' '05:42,46'
#  '19:36,71' '07:59,53' '03:16,56' '20:57,88' '05:33,95' '00:26,28'
#  '16:04,95' '03:55,27' '19:39,05' '22:27,39' '17:23,16' '18:40,39'
#  '15:50,59' '18:51,17' '23:00,00' '05:24,90' '07:39,17' '22:17,38'
#  '16:53,24' '05:51,76' '14:42,64' '06:04,42' '00:48,46' '01:40,10'
#  '19:40,02' '04:42,27' '08:57,16' '18:38,79' '11:36,73' '03:18,02'
#  '05:14,51' '02:47,88' '16:57,04' '05:34,59' '19:05,94' '21:58,33'
#  '16:08,65' '15:00,00' '03:10,50' '10:16,29' '10:41,53' '07:04,24'
#  '08:51,37' '02:20,65' '12:26,99' '15:13,21' '21:11,26' '08:41,70'
#  '17:22,49' '13:06,96' '21:02,93' '12:26,52' '06:49,74' '20:35,28'
#  '00:55,91' '07:15,48' '22:41,84' '10:14,72']

# %%
# Cleaning and converting specific columns to numeric types

# Replace any non-numeric characters in the 'Dec (Declinaison)' column with an empty string and convert the column to float type
df['Dec (Declinaison)'] = df['Dec (Declinaison)'].replace(r'[^\d\.\-]', '', regex=True).astype(float)

# Replace any non-numeric characters in the 'RA (Right Ascension / Ascension droite)' column with an empty string and convert the column to float type
df['RA (Right Ascension / Ascension droite)'] = df['RA (Right Ascension / Ascension droite)'].replace(r'[^\d\.\-]', '', regex=True).astype(float)

# %%
# Printing the first few entries of the cleaned and converted columns

# Print the first five values in the 'Dec (Declinaison)' column to verify the cleaning and conversion process
print(df['Dec (Declinaison)'].head())

# Print the first five values in the 'RA (Right Ascension / Ascension droite)' column to verify the cleaning and conversion process
print(df['RA (Right Ascension / Ascension droite)'].head())
# Out:
# 0    -95332.0
# 1   -694807.0
# 2    312856.0
# 3    504327.0
# 4    322328.0
# Name: Dec (Declinaison), dtype: float64
# 0    155418.0
# 1    132439.0
# 2    234664.0
# 3     21107.0
# 4     44213.0
# Name: RA (Right Ascension / Ascension droite), dtype: float64

# %%
# Checking for missing values and handling them

# Print the number of missing values in the 'Dec (Declinaison)' column
print(df['Dec (Declinaison)'].isna().sum())

# Print the number of missing values in the 'RA (Right Ascension / Ascension droite)' column
print(df['RA (Right Ascension / Ascension droite)'].isna().sum())

# Drop rows where either 'Dec (Declinaison)' or 'RA (Right Ascension / Ascension droite)' is missing
df = df.dropna(subset=['Dec (Declinaison)', 'RA (Right Ascension / Ascension droite)'])

# Print the first five values in the 'Dec (Declinaison)' column after dropping rows with missing values
print(df['Dec (Declinaison)'].head())

# Print the first five values in the 'RA (Right Ascension / Ascension droite)' column after dropping rows with missing values
print(df['RA (Right Ascension / Ascension droite)'].head())
# Out:
# 0
# 0
# 0    -95332.0
# 1   -694807.0
# 2    312856.0
# 3    504327.0
# 4    322328.0
# Name: Dec (Declinaison), dtype: float64
# 0    155418.0
# 1    132439.0
# 2    234664.0
# 3     21107.0
# 4     44213.0
# Name: RA (Right Ascension / Ascension droite), dtype: float64

# %%
# Ensuring the columns are correctly converted to float type and verifying the conversion

# Convert the 'Dec (Declinaison)' column to float type
df['Dec (Declinaison)'] = df['Dec (Declinaison)'].astype(float)

# Convert the 'RA (Right Ascension / Ascension droite)' column to float type
df['RA (Right Ascension / Ascension droite)'] = df['RA (Right Ascension / Ascension droite)'].astype(float)

# Print the first five values in the 'Dec (Declinaison)' column to verify the conversion
print(df['Dec (Declinaison)'].head())

# Print the first five values in the 'RA (Right Ascension / Ascension droite)' column to verify the conversion
print(df['RA (Right Ascension / Ascension droite)'].head())
# Out:
# 0    -95332.0
# 1   -694807.0
# 2    312856.0
# 3    504327.0
# 4    322328.0
# Name: Dec (Declinaison), dtype: float64
# 0    155418.0
# 1    132439.0
# 2    234664.0
# 3     21107.0
# 4     44213.0
# Name: RA (Right Ascension / Ascension droite), dtype: float64

# %%
# Encoding categorical variables using one-hot encoding and displaying the first few rows of the resulting DataFrame

# Apply one-hot encoding to the specified categorical columns
df_encoded = pd.get_dummies(df, columns=[
    "Constellation zone (celestial equator) / Zone de la constellation (équateur céleste)", 
    "Constellation zone (ecliptic) / Zone de la constellation (écliptique)"
])

# Display the first five rows of the encoded DataFrame to verify the encoding process
df_encoded.head()
# Out:
#            Observation Season / Saison d'observation IAU code  \
# 0                                       Summer / Été      Sct
# 1  Southern hemisphere constellation / Constellat...      Vol
# 2  Southern hemisphere constellation / Constellat...      Tuc
# 3                                 Spring / Printemps      UMa
# 4                                   Autumn / Automne      Tri
#
#   Latin name / Nom latin  French name / Nom français   \
# 0                  Scutum           L’Écu de Sobieski
# 1                  Volans              Poisson volant
# 2                  Tucana                      Toucan
# 3              Ursa Major                Grande Ourse
# 4              Triangulum                    Triangle
#
#   English name / Nom en anglais  \
# 0                        Shield
# 1                   Flying Fish
# 2                        Toucan
# 3                      Big Bear
# 4                      Triangle
#
#    Constellation area in square degrees / Étendue de la constellation en degrés carrés  \
# 0                                            109.114
# 1                                            141.354
# 2                                            294.557
# 3                                           1279.660
# 4                                            131.847
#
#    Dec (Declinaison)  RA (Right Ascension / Ascension droite)  \
# 0           -95332.0                                 155418.0
# 1          -694807.0                                 132439.0
# 2           312856.0                                 234664.0
# 3           504327.0                                  21107.0
# 4           322328.0                                  44213.0
#
#   Principal star / Étoile principale  \
# 0                            α Scuti
# 1                         β Volantis
# 2                          α Tucanae
# 3                             Alioth
# 4                        β Trianguli
#
#   Constellation area in % of the celestial sphere / Étendue de la constellation en % de la sphère céleste  \
# 0                                             0,26 %
# 1                                             0,34 %
# 2                                             0,71 %
# 3                                             3,10 %
# 4                                             0,32 %
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 12  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 13  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 2  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 3  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 4  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 5  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 6  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 7  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 8  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 9
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 36 columns]

# %%
# Printing the columns of the encoded DataFrame to verify the one-hot encoding
# Print the columns of the encoded DataFrame
print(df_encoded.columns)
# Out:
# Index(['Observation Season / Saison d'observation', 'IAU code',
#        'Latin name / Nom latin ', 'French name / Nom français ',
#        'English name / Nom en anglais',
#        'Constellation area in square degrees / Étendue de la constellation en degrés carrés',
#        'Dec (Declinaison)', 'RA (Right Ascension / Ascension droite)',
#        'Principal star / Étoile principale',
#        'Constellation area in % of the celestial sphere / Étendue de la constellation en % de la sphère céleste',
#        'Constellation zone (Milky Way) / Zone de la constellation (Voie Lactée)',
#        'Quad', 'Name origin / Origine de l'apellation', 'Image',
#        'Constellation zone (celestial equator) / Zone de la constellation (équateur céleste)_Equatorial constellation',
#        'Constellation zone (celestial equator) / Zone de la constellation (équateur céleste)_North constellation',
#        'Constellation zone (celestial equator) / Zone de la constellation (équateur céleste)_North constellation - North Celestial pole',
#        'Constellation zone (celestial equator) / Zone de la constellation (équateur céleste)_South constellation',
#        'Constellation zone (celestial equator) / Zone de la constellation (équateur céleste)_South constellation - PSouth constellation',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_North ecliptic constellation',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_North ecliptic pole',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_South ecliptic constellation',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_South ecliptic pole',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 1',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 10',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 11',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 12',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 13',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 2',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 3',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 4',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 5',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 6',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 7',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 8',
#        'Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 9'],
#       dtype='object')

# %%
# Preparing feature matrix X and target matrix y for modeling

# Create the feature matrix X by dropping the specified columns
# The 'errors='ignore'' parameter ensures that if any of the columns to drop do not exist, no error is raised
X = df_encoded.drop([
    'Latin name / Nom latin', 
    'French name / Nom français', 
    'English name / Nom en anglais', 
    'Principal star / Étoile principale'
], axis=1, errors='ignore')

# Create the target matrix y by selecting the specified columns
y = df_encoded[['Dec (Declinaison)', 'RA (Right Ascension / Ascension droite)', 'Constellation area in square degrees / Étendue de la constellation en degrés carrés']]

# %%
# Print the data types of each column in the feature matrix X
print(X.dtypes)
# Identify non-numeric columns in the feature matrix X
# select_dtypes(include=['object']) selects columns with data type 'object' (typically strings or categorical data)
non_numeric_cols = X.select_dtypes(include=['object']).columns
# Print the list of non-numeric columns
print(non_numeric_cols)
# Out:
# Observation Season / Saison d'observation                                                                                           object
# IAU code                                                                                                                            object
# Latin name / Nom latin                                                                                                              object
# French name / Nom français                                                                                                          object
# Constellation area in square degrees / Étendue de la constellation en degrés carrés                                                float64
# Dec (Declinaison)                                                                                                                  float64
# RA (Right Ascension / Ascension droite)                                                                                            float64
# Constellation area in % of the celestial sphere / Étendue de la constellation en % de la sphère céleste                             object
# Constellation zone (Milky Way) / Zone de la constellation (Voie Lactée)                                                             object
# Quad                                                                                                                                object
# Name origin / Origine de l'apellation                                                                                               object
# Image                                                                                                                               object
# Constellation zone (celestial equator) / Zone de la constellation (équateur céleste)_Equatorial constellation                         bool
# Constellation zone (celestial equator) / Zone de la constellation (équateur céleste)_North constellation                              bool
# Constellation zone (celestial equator) / Zone de la constellation (équateur céleste)_North constellation - North Celestial pole       bool
# Constellation zone (celestial equator) / Zone de la constellation (équateur céleste)_South constellation                              bool
# Constellation zone (celestial equator) / Zone de la constellation (équateur céleste)_South constellation - PSouth constellation       bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_North ecliptic constellation                                    bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_North ecliptic pole                                             bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_South ecliptic constellation                                    bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_South ecliptic pole                                             bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 1                                      bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 10                                     bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 11                                     bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 12                                     bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 13                                     bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 2                                      bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 3                                      bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 4                                      bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 5                                      bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 6                                      bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 7                                      bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 8                                      bool
# Constellation zone (ecliptic) / Zone de la constellation (écliptique)_Zodiacal constellation # 9                                      bool
# dtype: object
# Index(['Observation Season / Saison d'observation', 'IAU code',
#        'Latin name / Nom latin ', 'French name / Nom français ',
#        'Constellation area in % of the celestial sphere / Étendue de la constellation en % de la sphère céleste',
#        'Constellation zone (Milky Way) / Zone de la constellation (Voie Lactée)',
#        'Quad', 'Name origin / Origine de l'apellation', 'Image'],
#       dtype='object')

# %%
# One-hot encoding categorical features, splitting data, and scaling features
# One-hot encode the non-numeric columns in the feature matrix X
# 'drop_first=True' ensures that the first category is dropped to avoid multicollinearity
X_encoded = pd.get_dummies(X, columns=non_numeric_cols, drop_first=True)

# Split the encoded feature matrix X and target matrix y into training and test sets
# 20% of the data is used for testing, and 80% is used for training
# 'random_state=42' ensures reproducibility of the split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Initialize a StandardScaler for feature scaling
scaler = StandardScaler()

# Fit the scaler on the training data and transform the training data
X_train_scaled = scaler.fit_transform(X_train)

# Transform the test data using the fitted scaler
X_test_scaled = scaler.transform(X_test)

# %%
# Convert all columns in the feature matrix X to numeric types, coercing any errors to NaN
X = X.apply(pd.to_numeric, errors='coerce')
# Drop rows with any NaN values in the feature matrix X
X = X.dropna()

# %%
# Initialize a dictionary to hold different regression models
models = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(),
    'Lasso Regression': Lasso(),
    'Random Forest Regressor': RandomForestRegressor(),
}

# Dictionary to store the performance results of each model
results = {}

# Iterate over the models dictionary
for name, model in models.items():
    # Fit the model on the scaled training data
    model.fit(X_train_scaled, y_train)
    
    # Make predictions on the scaled test data
    y_pred = model.predict(X_test_scaled)
    
    # Calculate Mean Squared Error (MSE) and R-squared (R2) score for the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    # Store the results in the results dictionary
    results[name] = {'MSE': mse, 'R2': r2}
    
    # Print the performance metrics for the current model
    print(f"{name}: MSE = {mse:.2f}, R2 = {r2:.2f}")
# Out:
# Linear Regression: MSE = 17859509143.45, R2 = 0.46
# Ridge Regression: MSE = 17826542091.24, R2 = 0.46
# Lasso Regression: MSE = 5715162453.44, R2 = 0.96
# Random Forest Regressor: MSE = 1269533004.42, R2 = 0.49

# %%
# Initialize regression models
models = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(),
    'Lasso Regression': Lasso(),
    'Random Forest Regressor': RandomForestRegressor(),
}

# Dictionary to store the performance metrics for each model
results = {}

# Iterate over each model in the models dictionary
for name, model in models.items():
    # Train the model using the scaled training data
    model.fit(X_train_scaled, y_train)
    
    # Predict the target values for the scaled test data
    y_pred = model.predict(X_test_scaled)
    
    # Calculate Mean Squared Error (MSE) and R-squared (R2) score
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    # Store the metrics in the results dictionary
    results[name] = {'MSE': mse, 'R2': r2}
    
    # Print the performance metrics for the current model
    print(f"{name}: MSE = {mse:.2f}, R2 = {r2:.2f}")

# Convert the results dictionary into a DataFrame
results_df = pd.DataFrame(results).T

# Sort the DataFrame by the R2 score in descending order
results_df.sort_values(by='R2', ascending=False, inplace=True)

# Display the sorted DataFrame
results_df
# Out:
# Linear Regression: MSE = 17859509143.45, R2 = 0.46
# Ridge Regression: MSE = 17826542091.24, R2 = 0.46
# Lasso Regression: MSE = 5715162453.44, R2 = 0.96
# Random Forest Regressor: MSE = 1306308348.49, R2 = 0.48
#                                   MSE        R2
# Lasso Regression         5.715162e+09  0.964979
# Random Forest Regressor  1.306308e+09  0.478690
# Ridge Regression         1.782654e+10  0.459775
# Linear Regression        1.785951e+10  0.456319

# %%
# Import seaborn for advanced visualization
import seaborn as sns

# Plot Mean Squared Error (MSE) for various models
plt.figure(figsize=(12, 6))
sns.barplot(x=results_df.index, y='MSE', data=results_df, palette='viridis')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Model')  # Label for the x-axis
plt.ylabel('Mean Squared Error (MSE)')  # Label for the y-axis
plt.title('Mean Squared Error of Various Models')  # Title of the plot
plt.grid(True)  # Add grid lines for better readability
plt.show()  # Display the plot

# Plot R² Score for various models
plt.figure(figsize=(12, 6))
sns.barplot(x=results_df.index, y='R2', data=results_df, palette='viridis')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Model')  # Label for the x-axis
plt.ylabel('R² Score')  # Label for the y-axis
plt.title('R² Score of Various Models')  # Title of the plot
plt.grid(True)  # Add grid lines for better readability
plt.show()  # Display the plot
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17248\2504200963.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=results_df.index, y='MSE', data=results_df, palette='viridis')
# C:\Users\hp\AppData\Local\Temp\ipykernel_17248\2504200963.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=results_df.index, y='R2', data=results_df, palette='viridis')

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Define time intervals from 0 to 1 million years, with 100 points
time_intervals = np.linspace(0, 1e6, 100) 

# Compute distances for a star-forming region using a sine function
distances_star_forming_region = np.sin(time_intervals / 1e6)

# Compute distances for the nearest star using a cosine function
distances_nearest_star = np.cos(time_intervals / 1e6)

# Create a new figure with a specified size
plt.figure(figsize=(10, 6))

# Plot the distances for the star-forming region
plt.plot(time_intervals, distances_star_forming_region, label='Star-Forming Region', color='blue')

# Plot the distances for the nearest star
plt.plot(time_intervals, distances_nearest_star, label='Nearest Star', color='red')

# Label the x-axis
plt.xlabel('Time (years)')
# Label the y-axis
plt.ylabel('Distance Change')
# Set the title of the plot
plt.title('Change in Distance Over Time')
# Add a legend to the plot
plt.legend()
# Add a grid to the plot for better readability
plt.grid(True)
# Display the plot
plt.show()
